# %% [markdown]
# # Clone and Install Dependencies

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 15637 (delta 123), reused 171 (delta 100), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.58 MiB | 23.74 MiB/s, done.
# Resolving deltas: 100% (10652/10652), done.
# /content/yolov5

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Train the Model

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#   inflating: data.yaml
#    creating: train/images/
#   inflating: train/images/Amphiprora (1).jpg
#   inflating: train/images/Amphiprora (2).jpg
#   inflating: train/images/Amphiprora (3).jpg
#   inflating: train/images/Amphora (1).jpg
#   inflating: train/images/Amphora (10).jpg
#   inflating: train/images/Amphora (12).jpg
#   inflating: train/images/Amphora (13).jpg
#   inflating: train/images/Amphora (15).jpg
#   inflating: train/images/Amphora (16).jpg
#   inflating: train/images/Amphora (2).jpg
#   inflating: train/images/Amphora (3).jpg
#   inflating: train/images/Amphora (4).jpg
#   inflating: train/images/Amphora (6).jpg
#   inflating: train/images/Amphora (7).jpg
#   inflating: train/images/Amphora (8).jpg
#   inflating: train/images/Anabaena (1).jpg
#   inflating: train/images/Anabaena (10).jpg
#   inflating: train/images/Anabaena (11).jpg
#   inflating: train/images/Anabaena (13).jpg
#   inflating: train/images/Anabaena (14).jpg
# ...

# %%
# !python train.py --img 640 --batch 32 --epochs 200 --data data.yaml --weights yolov5m6.pt --cache
# Out:
# train: weights=yolov5m6.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 30 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-132-ga82132c Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
from google.colab import files
# !zip -r '/content/exp.zip' '/content/yolov5/runs/train/exp'
files.download('/content/exp.zip')
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 16%)
#   adding: content/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 16%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 8%)
#   adding: content/yolov5/runs/train/exp/results.png (deflated 11%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 34%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/PR_curve.png (deflated 10%)
#   adding: content/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 17%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 14%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 8%)
# ...
